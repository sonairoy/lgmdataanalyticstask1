# %% [markdown]
# # **IMPORT LIBRARIES**

# %%
from google.colab.patches import cv2_imshow
from google.colab import drive
from google.colab import files 
import cv2
import matplotlib.pyplot as plt

# %% [markdown]
# # **READ PHOTO**

# %%
img=cv2.imread("Doraemon.png")

# %% [markdown]
# # **SHOW IMAGE USING OpenCV**

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=220x229 at 0x7F22F3962110>

# %% [markdown]
# # **Display Using Matplotlib**

# %%
plt.imshow(img)
plt.axis(False)
plt.show()

# %% [markdown]
# # **Matplotlib vs OpenCV**

# %% [markdown]
# We can observe that the image displayed using matplotlib is not consistent with the original image.
# This is because OpenCV uses BGR color scheme whereas matplotlib uses RGB colors scheme.
# We can convert BGR image to RGB by using any of the following methods.

# %% [markdown]
# # **Convert BGR to RGB: Method 1**

# %%
plt.imshow(img[:,:,::-1])
plt.axis(False)
plt.show()

# %% [markdown]
# # **Convert BGR to RGB: Method 1**

# %%
RGB_img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)
plt.imshow(RGB_img)
plt.axis(False)
plt.show()

# %% [markdown]
# # **Convert Image to a Pencil Sketch**

# %% [markdown]
# Converting a photo to pencil sketch involves the following steps:

# %% [markdown]
# # **Step 1: Convert to Grey Image**

# %%
grey_img=cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)

# %%
cv2_imshow(grey_img)
# Out:
# <PIL.Image.Image image mode=L size=220x229 at 0x7F22E6F075D0>

# %% [markdown]
# # **Step 2: Invert Image**

# %%
invert_img=cv2.bitwise_not(grey_img)
#invert_img=255-grey_img
cv2_imshow(invert_img)
# Out:
# <PIL.Image.Image image mode=L size=220x229 at 0x7F22E6E93150>

# %% [markdown]
# # **Step 3: Blur image**

# %%
blur_img=cv2.GaussianBlur(invert_img, (111,111),0)
cv2_imshow(blur_img)
# Out:
# <PIL.Image.Image image mode=L size=220x229 at 0x7F22E6E938D0>

# %% [markdown]
# # **Step 4: Invert Blurred Image**

# %%
invblur_img=cv2.bitwise_not(blur_img)
#invblur_img=255-blur_img
cv2_imshow(invblur_img)
# Out:
# <PIL.Image.Image image mode=L size=220x229 at 0x7F22E6E93D90>

# %% [markdown]
# # **Step 5: Sketch**

# %%
sketch_img=cv2.divide(grey_img,invblur_img, scale=256.0)
cv2_imshow(sketch_img)
# Out:
# <PIL.Image.Image image mode=L size=220x229 at 0x7F22E6E9F750>

# %% [markdown]
# # **Original Image vs Sketch**

# %%
plt.figure(figsize=(14,8))
plt.subplot(1,2,1)
plt.title('Original image', size=18)
plt.imshow(RGB_img)
plt.axis('off')
plt.subplot(1,2,2)
plt.title('Sketch', size=18)
rgb_sketch=cv2.cvtColor(sketch_img, cv2.COLOR_BGR2RGB)
plt.imshow(rgb_sketch)
plt.axis('off')
plt.show()
